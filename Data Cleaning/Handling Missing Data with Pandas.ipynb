# %% [markdown]
# # Handling Missing Data with Pandas
#
# pandas borrows all the capabilities from numpy selection + adds a number of convenient methods to handle missing values. Let's see one at a time:

# %% [markdown]
# <div style="height:20px; background: linear-gradient(to right, #ff7e5f, #feb47b); border-radius:2px;"></div>

# %% [markdown]
# ## Hands on!

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Pandas utility functions
#
# Similarly to `numpy`, pandas also has a few utility functions to identify and detect null values:

# %%
pd.isnull(np.nan)
# Out:
# True

# %%
pd.isnull(None)
# Out:
# True

# %%
pd.isna(np.nan)
# Out:
# True

# %%
pd.isna(None)
# Out:
# True

# %% [markdown]
# The opposite ones also exists:

# %%
pd.notnull(None)
# Out:
# False

# %%
pd.notnull(np.nan)
# Out:
# False

# %%
pd.notna(np.nan)
# Out:
# False

# %%
pd.notnull(3)
# Out:
# True

# %% [markdown]
# These functions also work with Series and `DataFrame`s:

# %%
pd.isnull(pd.Series([1, np.nan, 7]))
# Out:
# 0    False
# 1     True
# 2    False
# dtype: bool

# %%
pd.notnull(pd.Series([1, np.nan, 7]))
# Out:
# 0     True
# 1    False
# 2     True
# dtype: bool

# %%
pd.isnull(pd.DataFrame({
    'Column A': [1, np.nan, 7],
    'Column B': [np.nan, 2, 3],
    'Column C': [np.nan, 2, np.nan]
}))
# Out:
#    Column A  Column B  Column C
# 0     False      True      True
# 1      True     False     False
# 2     False     False      True

# %% [markdown]
# <div style="height:20px; background: linear-gradient(to right, #ff7e5f, #feb47b); border-radius:2px;"></div>

# %% [markdown]
# ### Pandas Operations with Missing Values
#
# Pandas manages missing values more gracefully than numpy. `nan`s will no longer behave as "viruses", and operations will just ignore them completely:

# %%
pd.Series([1, 2, np.nan]).count()
# Out:
# np.int64(2)

# %%
pd.Series([1, 2, np.nan]).sum()
# Out:
# np.float64(3.0)

# %%
pd.Series([2, 2, np.nan]).mean()
# Out:
# np.float64(2.0)

# %% [markdown]
# ### Filtering missing data
#
# As we saw with numpy, we could combine boolean selection + `pd.isnull` to filter out those `nan`s and null values:

# %%
s = pd.Series([1, 2, 3, np.nan, np.nan, 4])

# %%
pd.notnull(s)
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
pd.isnull(s)
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
pd.notnull(s).sum()
# Out:
# np.int64(4)

# %%
pd.isnull(s).sum()
# Out:
# np.int64(2)

# %%
s[pd.notnull(s)]
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 5    4.0
# dtype: float64

# %% [markdown]
# But both `notnull` and `isnull` are also methods of `Series` and `DataFrame`s, so we could use it that way:

# %%
s.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %%
s.notnull()
# Out:
# 0     True
# 1     True
# 2     True
# 3    False
# 4    False
# 5     True
# dtype: bool

# %%
s[s.notnull()]
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 5    4.0
# dtype: float64

# %% [markdown]
# <div style="height:20px; background: linear-gradient(to right, #ff7e5f, #feb47b); border-radius:2px;"></div>

# %% [markdown]
# ### Dropping null values

# %% [markdown]
# Boolean selection + `notnull()` seems a little bit verbose and repetitive. And as we said before: any repetitive task will probably have a better, more DRY way. In this case, we can use the `dropna` method:

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    NaN
# 5    4.0
# dtype: float64

# %%
s.dropna()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 5    4.0
# dtype: float64

# %% [markdown]
# ### Dropping null values on DataFrames
#
# You saw how simple it is to drop `na`s with a Series. But with `DataFrame`s, there will be a few more things to consider, because you can't drop single values. You can only drop entire columns or rows. Let's start with a sample `DataFrame`:

# %%
df = pd.DataFrame({
    'Column A': [1, np.nan, 30, np.nan],
    'Column B': [2, 8, 31, np.nan],
    'Column C': [np.nan, 9, 32, 100],
    'Column D': [5, 8, 34, 110],
})

# %%
df
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.shape
# Out:
# (4, 4)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   Column A  2 non-null      float64
#  1   Column B  3 non-null      float64
#  2   Column C  3 non-null      float64
#  3   Column D  4 non-null      int64
# dtypes: float64(3), int64(1)
# memory usage: 260.0 bytes

# %%
df.isnull()
# Out:
#    Column A  Column B  Column C  Column D
# 0     False     False      True     False
# 1      True     False     False     False
# 2     False     False     False     False
# 3      True      True     False     False

# %%
df.isnull().sum()
# Out:
# Column A    2
# Column B    1
# Column C    1
# Column D    0
# dtype: int64

# %%
df.dropna()
# Out:
#    Column A  Column B  Column C  Column D
# 2      30.0      31.0      32.0        34

# %%
df.dropna(axis=1) # axis='columns' also works
# Out:
#    Column D
# 0         5
# 1         8
# 2        34
# 3       110

# %% [markdown]
# In this case, any row or column that contains **at least** one null value will be dropped. Which can be, depending on the case, too extreme. You can control this behavior with the `how` parameter. Can be either `'any'` or `'all'`:

# %%
df2 = pd.DataFrame({
    'Column A': [1, np.nan, 30],
    'Column B': [2, np.nan, 31],
    'Column C': [np.nan, np.nan, 100]
})

# %%
df2
# Out:
#    Column A  Column B  Column C
# 0       1.0       2.0       NaN
# 1       NaN       NaN       NaN
# 2      30.0      31.0     100.0

# %%
df.dropna(how='all')
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.dropna(how='any') # default behavior
# Out:
#    Column A  Column B  Column C  Column D
# 2      30.0      31.0      32.0        34

# %% [markdown]
# You can also use the `thresh` parameter to indicate a _threshold_ (a minimum number) of non-null values for the row/column to be kept:

# %%
df
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.dropna(thresh=3)
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34

# %%
df.dropna(thresh=3, axis='columns')
# Out:
#    Column B  Column C  Column D
# 0       2.0       NaN         5
# 1       8.0       9.0         8
# 2      31.0      32.0        34
# 3       NaN     100.0       110

# %% [markdown]
# <div style="height:20px; background: linear-gradient(to right, #ff7e5f, #feb47b); border-radius:2px;"></div>

# %% [markdown]
# ### Filling null values
#
# Sometimes instead than dropping the null values, we might need to replace them with some other value. This highly depends on your context and the dataset you're currently working. Sometimes a `nan` can be replaced with a `0`, sometimes it can be replaced with the `mean` of the sample, and some other times you can take the closest value. Again, it depends on the context. We'll show you the different methods and mechanisms and you can then apply them to your own problem.

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    NaN
# 5    4.0
# dtype: float64

# %% [markdown]
# **Filling nulls with a arbitrary value**

# %%
s.fillna(0)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    0.0
# 4    0.0
# 5    4.0
# dtype: float64

# %%
s.fillna(s.mean())
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    2.5
# 4    2.5
# 5    4.0
# dtype: float64

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    NaN
# 5    4.0
# dtype: float64

# %% [markdown]
# **Filling nulls with contiguous (close) values**
#
# The `method` argument is used to fill null values with other values close to that null one:

# %%
s.fillna(method='ffill')
# Out:
# C:\Users\terry\AppData\Local\Temp\ipykernel_10140\1029756637.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   s.fillna(method='ffill')
# 0    1.0
# 1    2.0
# 2    3.0
# 3    3.0
# 4    3.0
# 5    4.0
# dtype: float64

# %%
s.fillna(method='bfill')
# Out:
# C:\Users\terry\AppData\Local\Temp\ipykernel_10140\1641295691.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   s.fillna(method='bfill')
# 0    1.0
# 1    2.0
# 2    3.0
# 3    4.0
# 4    4.0
# 5    4.0
# dtype: float64

# %% [markdown]
# This can still leave null values at the extremes of the Series/DataFrame:

# %%
pd.Series([np.nan, 3, np.nan, 9]).fillna(method='ffill')
# Out:
# C:\Users\terry\AppData\Local\Temp\ipykernel_10140\533636215.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.Series([np.nan, 3, np.nan, 9]).fillna(method='ffill')
# 0    NaN
# 1    3.0
# 2    3.0
# 3    9.0
# dtype: float64

# %%
pd.Series([1, np.nan, 3, np.nan, np.nan]).fillna(method='bfill')
# Out:
# C:\Users\terry\AppData\Local\Temp\ipykernel_10140\2629518188.py:1: FutureWarning: Series.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   pd.Series([1, np.nan, 3, np.nan, np.nan]).fillna(method='bfill')
# 0    1.0
# 1    3.0
# 2    3.0
# 3    NaN
# 4    NaN
# dtype: float64

# %% [markdown]
# ### Filling null values on DataFrames
#
# The `fillna` method also works on `DataFrame`s, and it works similarly. The main differences are that you can specify the `axis` (as usual, rows or columns) to use to fill the values (specially for methods) and that you have more control on the values passed:

# %%
df
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       NaN       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       NaN       NaN     100.0       110

# %%
df.fillna({'Column A': 0, 'Column B': 99, 'Column C': df['Column C'].mean()})
# Out:
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0      47.0         5
# 1       0.0       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3       0.0      99.0     100.0       110

# %%
df.fillna(method='ffill', axis=0)
# Out:
# C:\Users\terry\AppData\Local\Temp\ipykernel_10140\3122255136.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', axis=0)
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       NaN         5
# 1       1.0       8.0       9.0         8
# 2      30.0      31.0      32.0        34
# 3      30.0      31.0     100.0       110

# %%
df.fillna(method='ffill', axis=1)
# Out:
# C:\Users\terry\AppData\Local\Temp\ipykernel_10140\901808322.py:1: FutureWarning: DataFrame.fillna with 'method' is deprecated and will raise in a future version. Use obj.ffill() or obj.bfill() instead.
#   df.fillna(method='ffill', axis=1)
#    Column A  Column B  Column C  Column D
# 0       1.0       2.0       2.0       5.0
# 1       NaN       8.0       9.0       8.0
# 2      30.0      31.0      32.0      34.0
# 3       NaN       NaN     100.0     110.0

# %%
s.dropna().count()
# Out:
# np.int64(4)

# %%
missing_values = len(s.dropna()) != len(s)
missing_values
# Out:
# True

# %% [markdown]
# There's also a `count` method, that excludes `nan`s from its result:

# %%
len(s)
# Out:
# 6

# %%
s.count()
# Out:
# np.int64(4)

# %% [markdown]
# <div style="height:20px; background: linear-gradient(to right, #ff7e5f, #feb47b); border-radius:2px;"></div>

# %% [markdown]
# **More Pythonic solution `any`**
#
# The methods `any` and `all` check if either there's `any` True value in a Series or `all` the values are `True`. They work in the same way as in Python:

# %%
pd.Series([True, False, False]).any()
# Out:
# np.True_

# %%
pd.Series([True, False, False]).all()
# Out:
# np.False_

# %%
pd.Series([True, True, True]).all()
# Out:
# np.True_

# %% [markdown]
# The `isnull()` method returned a Boolean `Series` with `True` values wherever there was a `nan`:

# %%
s.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4     True
# 5    False
# dtype: bool

# %% [markdown]
# So we can just use the `any` method with the boolean array returned:

# %%
s
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    NaN
# 5    4.0
# dtype: float64

# %%
pd.Series([1, np.nan]).isnull().any()
# Out:
# np.True_

# %%
pd.Series([1, 2]).isnull().any()
# Out:
# np.False_

# %%
s.isnull().any()
# Out:
# np.True_

# %% [markdown]
# A more strict version would check only the `values` of the Series:

# %%
s.isnull().values
# Out:
# array([False, False, False,  True,  True, False])

# %%
s.isnull().values.any()
# Out:
# np.True_

# %% [markdown]
# <div style="height:20px; background: linear-gradient(to right, #ff7e5f, #feb47b); border-radius:2px;"></div>
