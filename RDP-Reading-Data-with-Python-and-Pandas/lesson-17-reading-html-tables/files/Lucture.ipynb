# %% [markdown]
# # Reading HTML tables
#
# In this lecture we'll learn how to read and parse HTML tables from websites into a list of `DataFrame` objects to work with.

# %% [markdown]
# <div style="height:20px; background: linear-gradient(to right, #ff7e5f, #feb47b); border-radius:2px;"></div>

# %% [markdown]
# ## Hands on!

# %%
# !pip install lxml
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: lxml in c:\users\terry\appdata\roaming\python\python313\site-packages (6.0.2)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# %% [markdown]
# <div style="height:20px; background: linear-gradient(to right, #ff7e5f, #feb47b); border-radius:2px;"></div>

# %% [markdown]
# ## Parsing raw HTML strings
#
# Another useful pandas method is `read_html()`. This method will read HTML tables from a given URL, a file-like object, or a raw string containing HTML, and return a list of `DataFrame` objects.
#
# Let's try to read the following `html_string` into a `DataFrame`.

# %%
html_string = """
<table>
    <thead>
      <tr>
        <th>Order date</th>
        <th>Region</th> 
        <th>Item</th>
        <th>Units</th>
        <th>Unit cost</th>
      </tr>
    </thead>
    <tbody>
      <tr>
        <td>1/6/2018</td>
        <td>East</td> 
        <td>Pencil</td>
        <td>95</td>
        <td>1.99</td>
      </tr>
      <tr>
        <td>1/23/2018</td>
        <td>Central</td> 
        <td>Binder</td>
        <td>50</td>
        <td>19.99</td>
      </tr>
      <tr>
        <td>2/9/2018</td>
        <td>Central</td> 
        <td>Pencil</td>
        <td>36</td>
        <td>4.99</td>
      </tr>
      <tr>
        <td>3/15/2018</td>
        <td>West</td> 
        <td>Pen</td>
        <td>27</td>
        <td>19.99</td>
      </tr>
    </tbody>
</table>
"""

# %%
dfs = pd.read_html(html_string)
# Out:
# C:\Users\terry\AppData\Local\Temp\ipykernel_15932\2234146965.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   dfs = pd.read_html(html_string)

# %% [markdown]
# The `read_html` just returned one `DataFrame` object:

# %%
len(dfs)
# Out:
# 1

# %%
df = dfs[0]

df
# Out:
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99
# 3  3/15/2018     West     Pen     27      19.99

# %% [markdown]
# Previous `DataFrame` looks quite similar to the raw HTML table, but now we have a `DataFrame` object, so we can apply any pandas operation we want to it.

# %%
df.shape
# Out:
# (4, 5)

# %%
df.loc[df['Region'] == 'Central']
# Out:
#   Order date   Region    Item  Units  Unit cost
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99

# %%
df.loc[df['Units'] > 35]
# Out:
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99

# %% [markdown]
# ### Defining header
#
# Pandas will automatically find the header to use thanks to the <thead> tag.
#
# But in many cases we'll find wrong or incomplete tables that make the `read_html` method parse the tables in a wrong way without the proper headers.
#
# To fix them we can use the `header` parameter.

# %%
html_string = """
<table>
  <tr>
    <td>Order date</td>
    <td>Region</td> 
    <td>Item</td>
    <td>Units</td>
    <td>Unit cost</td>
  </tr>
  <tr>
    <td>1/6/2018</td>
    <td>East</td> 
    <td>Pencil</td>
    <td>95</td>
    <td>1.99</td>
  </tr>
  <tr>
    <td>1/23/2018</td>
    <td>Central</td> 
    <td>Binder</td>
    <td>50</td>
    <td>19.99</td>
  </tr>
  <tr>
    <td>2/9/2018</td>
    <td>Central</td> 
    <td>Pencil</td>
    <td>36</td>
    <td>4.99</td>
  </tr>
  <tr>
    <td>3/15/2018</td>
    <td>West</td> 
    <td>Pen</td>
    <td>27</td>
    <td>19.99</td>
  </tr>
</table>
"""

# %%
pd.read_html(html_string)[0]
# Out:
# C:\Users\terry\AppData\Local\Temp\ipykernel_15932\2877898795.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(html_string)[0]
#             0        1       2      3          4
# 0  Order date   Region    Item  Units  Unit cost
# 1    1/6/2018     East  Pencil     95       1.99
# 2   1/23/2018  Central  Binder     50      19.99
# 3    2/9/2018  Central  Pencil     36       4.99
# 4   3/15/2018     West     Pen     27      19.99

# %% [markdown]
# In this case, we'll need to pass the row number to use as header using the `header` parameter.

# %%
pd.read_html(html_string, header=0)[0]
# Out:
# C:\Users\terry\AppData\Local\Temp\ipykernel_15932\3156000096.py:1: FutureWarning: Passing literal html to 'read_html' is deprecated and will be removed in a future version. To read from a literal string, wrap it in a 'StringIO' object.
#   pd.read_html(html_string, header=0)[0]
#   Order date   Region    Item  Units  Unit cost
# 0   1/6/2018     East  Pencil     95       1.99
# 1  1/23/2018  Central  Binder     50      19.99
# 2   2/9/2018  Central  Pencil     36       4.99
# 3  3/15/2018     West     Pen     27      19.99

# %% [markdown]
# <div style="height:20px; background: linear-gradient(to right, #ff7e5f, #feb47b); border-radius:2px;"></div>

# %% [markdown]
# ## Parsing HTML tables from the web
#
# Now that we know how `read_html` works, go one step beyond and try to parse HTML tables directly from an URL.
#
# To do that we'll call the `read_html` method with an URL as paramter.

# %%
html_url = "https://www.basketball-reference.com/leagues/NBA_2019_per_game.html"

# %%
nba_tables = pd.read_html(html_url)

# %%
len(nba_tables)
# Out:
# 2

# %% [markdown]
# We'll work with the only one table found:

# %%
nba = nba_tables[0]

# %%
nba.head()
# Out:
#     Rk                 Player   Age Team Pos     G    GS    MP    FG   FGA  \
# 0  1.0           James Harden  29.0  HOU  PG  78.0  78.0  36.8  10.8  24.5
# 1  2.0            Paul George  28.0  OKC  SF  77.0  77.0  36.9   9.2  21.0
# 2  3.0  Giannis Antetokounmpo  24.0  MIL  PF  72.0  72.0  32.8  10.0  17.3
# 3  4.0            Joel Embiid  24.0  PHI   C  64.0  64.0  33.7   9.1  18.7
# 4  5.0           LeBron James  34.0  LAL  SF  55.0  55.0  35.2  10.1  19.9
#
#    ...  ORB   DRB   TRB  AST  STL  BLK  TOV   PF   PTS  \
# 0  ...  0.8   5.8   6.6  7.5  2.0  0.7  5.0  3.1  36.1
# 1  ...  1.4   6.8   8.2  4.1  2.2  0.4  2.7  2.8  28.0
# 2  ...  2.2  10.3  12.5  5.9  1.3  1.5  3.7  3.2  27.7
# 3  ...  2.5  11.1  13.6  3.7  0.7  1.9  3.5  3.3  27.5
# 4  ...  1.0   7.4   8.5  8.3  1.3  0.6  3.6  1.7  27.4
#
#                       Awards
# 0              MVP-2,AS,NBA1
# 1  MVP-3,DPOY-3,AS,NBA1,DEF1
# 2  MVP-1,DPOY-2,AS,NBA1,DEF1
# 3  MVP-7,DPOY-4,AS,NBA2,DEF2
# 4             MVP-11,AS,NBA3
#
# [5 rows x 31 columns]

# %% [markdown]
# ### Complex example
#
# We can also use the `requests` module to get HTML code from an URL to parse it into `DataFrame` objects.
#
# If we look at the given URL we can see multiple tables about The Simpsons TV show.
#
# We want to keep the table with information about each season.

# %%
import requests
from io import StringIO

html_url = "https://en.wikipedia.org/wiki/The_Simpsons"
headers = {
    "User-Agent": "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
                  "AppleWebKit/537.36 (KHTML, like Gecko) "
                  "Chrome/141.0.0.0 Safari/537.36"
}

# %%
# !pip install html5lib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: html5lib in c:\users\terry\appdata\roaming\python\python313\site-packages (1.1)
# Requirement already satisfied: six>=1.9 in c:\users\terry\appdata\roaming\python\python313\site-packages (from html5lib) (1.17.0)
# Requirement already satisfied: webencodings in c:\users\terry\appdata\roaming\python\python313\site-packages (from html5lib) (0.5.1)
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
r = requests.get(html_url,headers=headers)

wiki_tables = pd.read_html(StringIO(r.text), header=0)

print(f"✅ Found {len(wiki_tables)} tables")
display(wiki_tables[0].head())
# Out:
# ✅ Found 50 tables
#    The Simpsons                                     The Simpsons.1
# 0           NaN                                                NaN
# 1         Genre                             Animated sitcom Satire
# 2    Created by                                      Matt Groening
# 3  Developed by            James L. Brooks Matt Groening Sam Simon
# 4   Showrunners  James L. Brooks Matt Groening Sam Simon Al Jea...

# %%
len(wiki_tables)
# Out:
# 50

# %%
Simpsons = wiki_tables[2]

# %%
Simpsons.head()
# Out:
#    Season Season.1  No. of episodes    Originally aired Originally aired.1  \
# 0  Season   Season  No. of episodes     Season premiere      Season finale
# 1  Season   Season  No. of episodes     Season premiere      Season finale
# 2       1  1989–90               13   December 17, 1989       May 13, 1990
# 3       2  1990–91               22    October 11, 1990      July 11, 1991
# 4       3  1991–92               24  September 19, 1991    August 27, 1992
#
#   Originally aired.2                               Viewership  \
# 0     Time slot (ET)  Avg. households / viewers (in millions)
# 1     Time slot (ET)  Avg. households / viewers (in millions)
# 2     Sunday 8:30 pm                        13.4m h.[n1][163]
# 3   Thursday 8:00 pm                         12.2m h.[n1][n2]
# 4   Thursday 8:00 pm                           12m h.[n1][n3]
#
#            Viewership.1             Viewership.2
# 0  Most watched episode     Most watched episode
# 1    Viewers (millions)            Episode title
# 2             33.5[164]  "Life on the Fast Lane"
# 3             33.6[165]       "Bart Gets an 'F'"
# 4             25.5[166]          "Colonel Homer"

# %% [markdown]
# Quick clean on the table: remove extra header rows and set `Season` as index.

# %%
Simpsons.drop([0, 1], inplace=True)

# %%
Simpsons.set_index('Season', inplace=True)

# %% [markdown]
# Which season has the lowest number of episodes?

# %%
Simpsons['No. of episodes'].unique()
# Out:
# array(['13', '22', '24', '25', '23', '21', '20', '18', '17'], dtype=object)

# %%
min_season = Simpsons['No. of episodes'].min()
min_season
# Out:
# '13'

# %%
Simpsons.loc[Simpsons['No. of episodes'] == min_season]
# Out:
#        Season.1 No. of episodes   Originally aired Originally aired.1  \
# Season
# 1       1989–90              13  December 17, 1989       May 13, 1990
#
#        Originally aired.2         Viewership Viewership.1  \
# Season
# 1          Sunday 8:30 pm  13.4m h.[n1][163]    33.5[164]
#
#                    Viewership.2
# Season
# 1       "Life on the Fast Lane"

# %% [markdown]
# <div style="height:20px; background: linear-gradient(to right, #ff7e5f, #feb47b); border-radius:2px;"></div>

# %%
## Save to CSV file

Finally save the `DataFrame` to a CSV file as we saw on previous lectures.

# %%
Simpsons.head()
# Out:
#        Season.1 No. of episodes    Originally aired Originally aired.1  \
# Season
# 1       1989–90              13   December 17, 1989       May 13, 1990
# 2       1990–91              22    October 11, 1990      July 11, 1991
# 3       1991–92              24  September 19, 1991    August 27, 1992
# 4       1992–93              22  September 24, 1992       May 13, 1993
# 5       1993–94              22  September 30, 1993       May 19, 1994
#
#        Originally aired.2         Viewership Viewership.1  \
# Season
# 1          Sunday 8:30 pm  13.4m h.[n1][163]    33.5[164]
# 2        Thursday 8:00 pm   12.2m h.[n1][n2]    33.6[165]
# 3        Thursday 8:00 pm     12m h.[n1][n3]    25.5[166]
# 4        Thursday 8:00 pm  12.1m h.[n1][167]    28.6[168]
# 5        Thursday 8:00 pm   10.5m h.[n1][n4]    24.0[169]
#
#                     Viewership.2
# Season
# 1        "Life on the Fast Lane"
# 2             "Bart Gets an 'F'"
# 3                "Colonel Homer"
# 4            "Lisa's First Word"
# 5       "Treehouse of Horror IV"

# %%
Simpsons.to_csv('out.csv')

# %%
pd.read_csv('out.csv', index_col='Season').head()
# Out:
#        Season.1  No. of episodes    Originally aired Originally aired.1  \
# Season
# 1       1989–90               13   December 17, 1989       May 13, 1990
# 2       1990–91               22    October 11, 1990      July 11, 1991
# 3       1991–92               24  September 19, 1991    August 27, 1992
# 4       1992–93               22  September 24, 1992       May 13, 1993
# 5       1993–94               22  September 30, 1993       May 19, 1994
#
#        Originally aired.2         Viewership Viewership.1  \
# Season
# 1          Sunday 8:30 pm  13.4m h.[n1][163]    33.5[164]
# 2        Thursday 8:00 pm   12.2m h.[n1][n2]    33.6[165]
# 3        Thursday 8:00 pm     12m h.[n1][n3]    25.5[166]
# 4        Thursday 8:00 pm  12.1m h.[n1][167]    28.6[168]
# 5        Thursday 8:00 pm   10.5m h.[n1][n4]    24.0[169]
#
#                     Viewership.2
# Season
# 1        "Life on the Fast Lane"
# 2             "Bart Gets an 'F'"
# 3                "Colonel Homer"
# 4            "Lisa's First Word"
# 5       "Treehouse of Horror IV"

# %% [markdown]
# <div style="height:20px; background: linear-gradient(to right, #ff7e5f, #feb47b); border-radius:2px;"></div>
